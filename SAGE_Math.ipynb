# %%
#Problems 24 and 25

# %%
x = var('x')

# %%
def f(x): return (exp(x) - exp(-x))/(exp(x) + exp(-x))

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -(e^(-x) - e^x)^2/(e^(-x) + e^x)^2 + 1

# %%
p = []

# %%
p.append(plot(f(x),(x,-5,5), color='blue', legend_label='f(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
table([(x,f(x)) for x in [-2..-0.01, step=.01]])
# Out:
#   -2.00000000000000     -0.964027580075817
#   -1.99000000000000     -0.963314218604513
#   -1.98000000000000     -0.962586980091291
#   -1.97000000000000     -0.961845605369484
#   -1.96000000000000     -0.961089830863614
#   -1.95000000000000     -0.960319388531845
#   -1.94000000000000     -0.959534005808429
#   -1.93000000000000     -0.958733405546187
#   -1.92000000000000     -0.957917305959064
#   -1.91000000000000     -0.957085420564793
#   -1.90000000000000     -0.956237458127739
#   -1.89000000000000     -0.955373122601935
#   -1.88000000000000     -0.954492113074392
#   -1.87000000000000     -0.953594123708712
#   -1.86000000000000     -0.952678843689078
#   -1.85000000000000     -0.951745957164661
#   -1.84000000000000     -0.950795143194521
#   -1.83000000000000     -0.949826075693040
#   -1.82000000000000     -0.948838423375984
#   -1.81000000000000     -0.947831849707234
#   -1.80000000000000     -0.946806012846268
#   -1.79000000000000     -0.945760565596474
# ...

# %%
table([(x,f(x)) for x in [0.01..2, step=.01]])
# Out:
#   0.0100000000000000   0.00999966667999938
#   0.0200000000000000   0.0199973337599309
#   0.0300000000000000   0.0299910032388202
#   0.0400000000000000   0.0399786803111636
#   0.0500000000000000   0.0499583749578800
#   0.0600000000000000   0.0599281035291435
#   0.0700000000000000   0.0698858903164290
#   0.0800000000000000   0.0798297691111314
#   0.0900000000000000   0.0897577847471601
#   0.100000000000000    0.0996679946249558
#   0.110000000000000    0.109558470214430
#   0.120000000000000    0.119427298534386
#   0.130000000000000    0.129272583606058
#   0.140000000000000    0.139092447878458
#   0.150000000000000    0.148885033623318
#   0.160000000000000    0.158648504297499
#   0.170000000000000    0.168381045870815
#   0.180000000000000    0.178080868117330
#   0.190000000000000    0.187746205868285
#   0.200000000000000    0.197375320224904
#   0.210000000000000    0.206966499729453
#   0.220000000000000    0.216518061493029
#   0.230000000000000    0.226028352278671
# ...

# %%
f(99999)
# Out:
# (e^99999 - e^(-99999))/(e^99999 + e^(-99999))

# %%
numerical_approx((e^99999 - e^(-99999))/(e^99999 + e^(-99999)))
# Out:
# 1.00000000000000

# %%
f(-99999)
# Out:
# -(e^99999 - e^(-99999))/(e^99999 + e^(-99999))

# %%
numerical_approx(-(e^99999 - e^(-99999))/(e^99999 + e^(-99999)))
# Out:
# -1.00000000000000
